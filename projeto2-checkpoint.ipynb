# %%
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# INTRODUCÃO ****

# %%
arquivo = pd.read_csv('winequalityN.csv')
arquivo

# tabela do vinho pega pela internet cvs
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
Novatabela = arquivo.loc[:, ['type', 'fixed acidity','volatile acidity','citric acid', 'residual sugar',
                           'density', 'pH', 'alcohol', 'quality']]

# %%
Novatabela
# filtro para so pegar as colunas que interessam
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       density    pH  alcohol  quality
# 0     1.00100  3.00      8.8        6
# 1     0.99400  3.30      9.5        6
# 2     0.99510  3.26     10.1        6
# 3     0.99560  3.19      9.9        6
# 4     0.99560  3.19      9.9        6
# ...       ...   ...      ...      ...
# 6492  0.99490  3.45     10.5        5
# 6493  0.99512  3.52     11.2        6
# 6494  0.99574  3.42     11.0        6
# 6495  0.99547  3.57     10.2        5
# 6496  0.99549  3.39     11.0        6
#
# [6497 rows x 9 columns]

# %%
Novatabela.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'density', 'pH', 'alcohol', 'quality'],
#       dtype='object')

# %%
novo= Novatabela.rename(columns= {"type": "tipo", "fixed acidity": "acidez", "volatile acidity": "volatilidadeAcida",
                                "citric acid": "AcidezCitrica", "residual sugar": "AçucarResidual","density": "densidade",
                               "pH": "pH", "alcohol": "álcool", "quality": "Qualidade"})
#criando um novo data frame para traduzir as colunas para portugues

# %%
# tipo novo

novo.loc[novo.tipo =='red', 'Tipo Binário'] = 1
novo.loc[novo.tipo =='white', 'Tipo Binário'] = 0
novo

# criando uma nova coluna em que tranformamos nosso target data em um estatististica quantitativa para que pudessemos aplicar nosso metodo de random forest
# Out:
#        tipo  acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# 0     white     7.0              0.270           0.36            20.7
# 1     white     6.3              0.300           0.34             1.6
# 2     white     8.1              0.280           0.40             6.9
# 3     white     7.2              0.230           0.32             8.5
# 4     white     7.2              0.230           0.32             8.5
# ...     ...     ...                ...            ...             ...
# 6492    red     6.2              0.600           0.08             2.0
# 6493    red     5.9              0.550           0.10             2.2
# 6494    red     6.3              0.510           0.13             2.3
# 6495    red     5.9              0.645           0.12             2.0
# 6496    red     6.0              0.310           0.47             3.6
#
#       densidade    pH  álcool  Qualidade  Tipo Binário
# 0       1.00100  3.00     8.8          6           0.0
# 1       0.99400  3.30     9.5          6           0.0
# 2       0.99510  3.26    10.1          6           0.0
# 3       0.99560  3.19     9.9          6           0.0
# 4       0.99560  3.19     9.9          6           0.0
# ...         ...   ...     ...        ...           ...
# 6492    0.99490  3.45    10.5          5           1.0
# 6493    0.99512  3.52    11.2          6           1.0
# 6494    0.99574  3.42    11.0          6           1.0
# 6495    0.99547  3.57    10.2          5           1.0
# 6496    0.99549  3.39    11.0          6           1.0
#
# [6497 rows x 10 columns]

# %%
novo
# Out:
#        tipo  acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# 0     white     7.0              0.270           0.36            20.7
# 1     white     6.3              0.300           0.34             1.6
# 2     white     8.1              0.280           0.40             6.9
# 3     white     7.2              0.230           0.32             8.5
# 4     white     7.2              0.230           0.32             8.5
# ...     ...     ...                ...            ...             ...
# 6492    red     6.2              0.600           0.08             2.0
# 6493    red     5.9              0.550           0.10             2.2
# 6494    red     6.3              0.510           0.13             2.3
# 6495    red     5.9              0.645           0.12             2.0
# 6496    red     6.0              0.310           0.47             3.6
#
#       densidade    pH  álcool  Qualidade  Tipo Binário
# 0       1.00100  3.00     8.8          6           0.0
# 1       0.99400  3.30     9.5          6           0.0
# 2       0.99510  3.26    10.1          6           0.0
# 3       0.99560  3.19     9.9          6           0.0
# 4       0.99560  3.19     9.9          6           0.0
# ...         ...   ...     ...        ...           ...
# 6492    0.99490  3.45    10.5          5           1.0
# 6493    0.99512  3.52    11.2          6           1.0
# 6494    0.99574  3.42    11.0          6           1.0
# 6495    0.99547  3.57    10.2          5           1.0
# 6496    0.99549  3.39    11.0          6           1.0
#
# [6497 rows x 10 columns]

# %% [markdown]
# QUAL METODO QUE USAMOS(RANDOM FOREST) OQUE ELE E NO QUE ELE AJUDA.

# %%
#Limpamos todos os dados nulos por meio dessas ferrafemtas

# Retirando data perdido no dataframe.
data_acidez = ~novo.acidez.isnull()
data_volatilidade = ~novo.volatilidadeAcida.isnull()
data_critica = ~novo.AcidezCitrica.isnull()
data_acucar = ~novo.AçucarResidual.isnull()
data_ph = ~novo.pH.isnull()
filtrado = novo[data_acidez & data_volatilidade & data_critica & data_acucar & data_ph].copy()
# Verificando as informações perdidas no dataset.
filtrado.isnull().sum()
# Out:
# tipo                 0
# acidez               0
# volatilidadeAcida    0
# AcidezCitrica        0
# AçucarResidual       0
# densidade            0
# pH                   0
# álcool               0
# Qualidade            0
# Tipo Binário         0
# dtype: int64

# %%
filtrado
# Out:
#        tipo  acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# 0     white     7.0              0.270           0.36            20.7
# 1     white     6.3              0.300           0.34             1.6
# 2     white     8.1              0.280           0.40             6.9
# 3     white     7.2              0.230           0.32             8.5
# 4     white     7.2              0.230           0.32             8.5
# ...     ...     ...                ...            ...             ...
# 6492    red     6.2              0.600           0.08             2.0
# 6493    red     5.9              0.550           0.10             2.2
# 6494    red     6.3              0.510           0.13             2.3
# 6495    red     5.9              0.645           0.12             2.0
# 6496    red     6.0              0.310           0.47             3.6
#
#       densidade    pH  álcool  Qualidade  Tipo Binário
# 0       1.00100  3.00     8.8          6           0.0
# 1       0.99400  3.30     9.5          6           0.0
# 2       0.99510  3.26    10.1          6           0.0
# 3       0.99560  3.19     9.9          6           0.0
# 4       0.99560  3.19     9.9          6           0.0
# ...         ...   ...     ...        ...           ...
# 6492    0.99490  3.45    10.5          5           1.0
# 6493    0.99512  3.52    11.2          6           1.0
# 6494    0.99574  3.42    11.0          6           1.0
# 6495    0.99547  3.57    10.2          5           1.0
# 6496    0.99549  3.39    11.0          6           1.0
#
# [6468 rows x 10 columns]

# %%
# separamos as colonas para mostrar nossas features e a nossa informacao alvo
X = filtrado.iloc[:,1:9].values # ESSES SAO OS FEATURES
Y = filtrado.iloc[:,9].values  # ESSE É O TARGET 
Z = X, Y

# %%
#separamos em duas tabelas uma teste e outra de treino
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
# Utilizamos o metodo random forest para prever o tipo de vinho 
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=20, random_state=0)
classifier.fit(X_train, y_train)
Y_pred = classifier.predict(X_test)
Y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# Vendo a acuracia
classifier.score(X_test, y_test)
# Out:
# 0.9829984544049459

# %%
fig, ax= plt.subplots(figsize=(8,8))

plot_confusion_matrix(classifier, X_test, y_test, normalize="all", display_labels=["Negativo", "Positivo"],
                     cmap="Reds", ax=ax, values_format=".2%")
plt.xlabel("Previsão")
plt.ylabel("Verdadeiro")
plt.title("Matriz de confusão")
plt.show()

# %% [markdown]
#  a acuracia é boa pq nesse metodo.

# %% [markdown]
# Vendo dados estatisticos da tabela e analisando seus valores

# %% [markdown]
# PEQUENA CONCLUSAO DO METODO

# %%
# vendo os dados estátísticos Básicos da tabela
novo.describe()
# Out:
#             acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# count  6487.000000        6489.000000    6494.000000     6495.000000
# mean      7.216579           0.339691       0.318722        5.444326
# std       1.296750           0.164649       0.145265        4.758125
# min       3.800000           0.080000       0.000000        0.600000
# 25%       6.400000           0.230000       0.250000        1.800000
# 50%       7.000000           0.290000       0.310000        3.000000
# 75%       7.700000           0.400000       0.390000        8.100000
# max      15.900000           1.580000       1.660000       65.800000
#
#          densidade           pH       álcool    Qualidade  Tipo Binário
# count  6497.000000  6488.000000  6497.000000  6497.000000   6497.000000
# mean      0.994697     3.218395    10.491801     5.818378      0.246114
# std       0.002999     0.160748     1.192712     0.873255      0.430779
# min       0.987110     2.720000     8.000000     3.000000      0.000000
# 25%       0.992340     3.110000     9.500000     5.000000      0.000000
# 50%       0.994890     3.210000    10.300000     6.000000      0.000000
# 75%       0.996990     3.320000    11.300000     6.000000      0.000000
# max       1.038980     4.010000    14.900000     9.000000      1.000000

# %%
novo.tipo.describe()
# Out:
# count      6497
# unique        2
# top       white
# freq       4898
# Name: tipo, dtype: object

# %%
novo.tipo.value_counts(True)
# Out:
# white    0.753886
# red      0.246114
# Name: tipo, dtype: float64

# %% [markdown]
# A partir da tabale criada usando a ferramenta describe() no dataset, podemos perceber que ha mais vinho branco que vermelho.

# %% [markdown]
# VAMOS ANALISAR OS TIPOS DE VINHO SEPARADAMENTE PARA VER SUAS ESTATISTICAS

# %%
novo[novo.tipo == 'white'].describe()
# Out:
#             acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# count  4890.000000        4891.000000    4896.000000     4896.000000
# mean      6.855532           0.278252       0.334250        6.393250
# std       0.843808           0.100811       0.120985        5.072275
# min       3.800000           0.080000       0.000000        0.600000
# 25%       6.300000           0.210000       0.270000        1.700000
# 50%       6.800000           0.260000       0.320000        5.200000
# 75%       7.300000           0.320000       0.390000        9.900000
# max      14.200000           1.100000       1.660000       65.800000
#
#          densidade           pH       álcool    Qualidade  Tipo Binário
# count  4898.000000  4891.000000  4898.000000  4898.000000        4898.0
# mean      0.994027     3.188203    10.514267     5.877909           0.0
# std       0.002991     0.151014     1.230621     0.885639           0.0
# min       0.987110     2.720000     8.000000     3.000000           0.0
# 25%       0.991723     3.090000     9.500000     5.000000           0.0
# 50%       0.993740     3.180000    10.400000     6.000000           0.0
# 75%       0.996100     3.280000    11.400000     6.000000           0.0
# max       1.038980     3.820000    14.200000     9.000000           0.0

# %%
novo[novo.tipo == 'red'].describe()
# Out:
#             acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# count  1597.000000        1598.000000    1598.000000     1599.000000
# mean      8.322104           0.527738       0.271145        2.538806
# std       1.740767           0.179085       0.194744        1.409928
# min       4.600000           0.120000       0.000000        0.900000
# 25%       7.100000           0.390000       0.090000        1.900000
# 50%       7.900000           0.520000       0.260000        2.200000
# 75%       9.200000           0.640000       0.420000        2.600000
# max      15.900000           1.580000       1.000000       15.500000
#
#          densidade           pH       álcool    Qualidade  Tipo Binário
# count  1599.000000  1597.000000  1599.000000  1599.000000        1599.0
# mean      0.996747     3.310864    10.422983     5.636023           1.0
# std       0.001887     0.154290     1.065668     0.807569           0.0
# min       0.990070     2.740000     8.400000     3.000000           1.0
# 25%       0.995600     3.210000     9.500000     5.000000           1.0
# 50%       0.996750     3.310000    10.200000     6.000000           1.0
# 75%       0.997835     3.400000    11.100000     6.000000           1.0
# max       1.003690     4.010000    14.900000     8.000000           1.0

# %% [markdown]
# Olhando para as duas tabelas acima,
# podemos concluir que o vinho vermelho é mais ácido que o vinho branco.
# Mostrando uma maior acidez em seus quartis e um maximo maior.

# %% [markdown]
# AQUI EXPLICAMOS SOBRE O METODO DECISION TREE PQ ELE É IMPORTANTE E COMO DEVE SER USADO

# %%
features = ['acidez', 'volatilidadeAcida', 'AcidezCitrica', 'AçucarResidual','densidade','pH','álcool', 'Qualidade']
X = filtrado[features] # Features
y = filtrado['Tipo Binário'] # Target variable
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(X, Y)
# decision_tree
# tree.plot_tree(clf)

# %%
features = ['acidez', 'volatilidadeAcida', 'AcidezCitrica', 'AçucarResidual','densidade','pH','álcool', 'Qualidade']

z = filtrado[features] # Features
p = filtrado['Tipo Binário'] # Target variable

z_train, z_test, p_train, p_test= train_test_split(z, p, test_size=0.3, random_state=1)

# %%
oi= DecisionTreeClassifier(criterion= "entropy")
oi.fit(z_train, p_train)
cara= oi.predict(z_test)

print(f"A acuracia é: {round((metrics.accuracy_score(p_test, cara)*100),2)}%")
# Out:
# A acuracia é: 98.25%

# %%
fig, ax= plt.subplots(figsize=(8,8))

plot_confusion_matrix(oi, z_test, p_test, normalize="all", display_labels=["Negativo", "Positivo"],
                     cmap="Greens", ax=ax, values_format=".2%")
plt.xlabel("Previsão")
plt.ylabel("Verdadeiro")
plt.title("Matriz de confusão")
plt.show()

# %%
feature=['acidez', 'volatilidadeAcida', 'AcidezCitrica', 'AçucarResidual', 'densidade', 'pH', 'álcool',
         'Qualidade']

# %%
sla= pd.Series(classifier.feature_importances_, index=feature).sort_values(ascending=False).round(5)*100
sla2= pd.Series(oi.feature_importances_, index=features).sort_values(ascending=False).round(5)*100

plt.figure(figsize=(13, 6))

plt.subplot(121)
sns.barplot(sla, sla.index, palette="Greens_d")
plt.title("Importância no modelo Random Forest")
plt.xlabel("importância")
plt.grid(True)

plt.subplot(122)
sns.barplot(sla2, sla2.index, palette="Greens_d")
plt.title("Importância no modelo Decision Tree")
plt.xlabel("importância")
plt.grid(True)

plt.tight_layout();

# %% [markdown]
# PEQUENA CONCLUSAO DO METODO

# %% [markdown]
# MELHORIAS QUE PODIAMOS FAZER

# %% [markdown]
# CONCLUSAO GERAL

# %% [markdown]
# REFERENCIAS
