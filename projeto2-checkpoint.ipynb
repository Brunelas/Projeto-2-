# %%
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# INTRODUCÃO ****

# %%
arquivo = pd.read_csv('winequalityN.csv')
arquivo

# tabela do vinho pega pela internet cvs
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
Novatabela = arquivo.loc[:,['type', 'fixed acidity','volatile acidity','citric acid', 'residual sugar',
                           'density', 'pH', 'alcohol', 'quality']]

# %%
Novatabela
# filtro para so pegar as colunas que interessam
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       density    pH  alcohol  quality
# 0     1.00100  3.00      8.8        6
# 1     0.99400  3.30      9.5        6
# 2     0.99510  3.26     10.1        6
# 3     0.99560  3.19      9.9        6
# 4     0.99560  3.19      9.9        6
# ...       ...   ...      ...      ...
# 6492  0.99490  3.45     10.5        5
# 6493  0.99512  3.52     11.2        6
# 6494  0.99574  3.42     11.0        6
# 6495  0.99547  3.57     10.2        5
# 6496  0.99549  3.39     11.0        6
#
# [6497 rows x 9 columns]

# %%
Novatabela.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'density', 'pH', 'alcohol', 'quality'],
#       dtype='object')

# %%
novo= Novatabela.rename(columns= {"type": "tipo", "fixed acidity": "acidez", "volatile acidity": "volatilidadeAcida",
                                "citric acid": "AcidezCitrica", "residual sugar": "AçucarResidual","density": "densidade",
                               "pH": "pH", "alcohol": "álcool", "quality": "Qualidade"})
#criando um novo data frame para traduzir as colunas para portugues

# %%
# tipo novo

novo.loc[novo.tipo =='red', 'Tipo Binário'] = 1
novo.loc[novo.tipo =='white', 'Tipo Binário'] = 0
novo

# criando uma nova coluna em que tranformamos nosso target data em um estatististica quantitativa para que pudessemos aplicar nosso metodo de random forest
# Out:
#        tipo  acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# 0     white     7.0              0.270           0.36            20.7
# 1     white     6.3              0.300           0.34             1.6
# 2     white     8.1              0.280           0.40             6.9
# 3     white     7.2              0.230           0.32             8.5
# 4     white     7.2              0.230           0.32             8.5
# ...     ...     ...                ...            ...             ...
# 6492    red     6.2              0.600           0.08             2.0
# 6493    red     5.9              0.550           0.10             2.2
# 6494    red     6.3              0.510           0.13             2.3
# 6495    red     5.9              0.645           0.12             2.0
# 6496    red     6.0              0.310           0.47             3.6
#
#       densidade    pH  álcool  Qualidade  Tipo Binário
# 0       1.00100  3.00     8.8          6           0.0
# 1       0.99400  3.30     9.5          6           0.0
# 2       0.99510  3.26    10.1          6           0.0
# 3       0.99560  3.19     9.9          6           0.0
# 4       0.99560  3.19     9.9          6           0.0
# ...         ...   ...     ...        ...           ...
# 6492    0.99490  3.45    10.5          5           1.0
# 6493    0.99512  3.52    11.2          6           1.0
# 6494    0.99574  3.42    11.0          6           1.0
# 6495    0.99547  3.57    10.2          5           1.0
# 6496    0.99549  3.39    11.0          6           1.0
#
# [6497 rows x 10 columns]

# %%
novo
# Out:
#        tipo  acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# 0     white     7.0              0.270           0.36            20.7
# 1     white     6.3              0.300           0.34             1.6
# 2     white     8.1              0.280           0.40             6.9
# 3     white     7.2              0.230           0.32             8.5
# 4     white     7.2              0.230           0.32             8.5
# ...     ...     ...                ...            ...             ...
# 6492    red     6.2              0.600           0.08             2.0
# 6493    red     5.9              0.550           0.10             2.2
# 6494    red     6.3              0.510           0.13             2.3
# 6495    red     5.9              0.645           0.12             2.0
# 6496    red     6.0              0.310           0.47             3.6
#
#       densidade    pH  álcool  Qualidade  Tipo Binário
# 0       1.00100  3.00     8.8          6           0.0
# 1       0.99400  3.30     9.5          6           0.0
# 2       0.99510  3.26    10.1          6           0.0
# 3       0.99560  3.19     9.9          6           0.0
# 4       0.99560  3.19     9.9          6           0.0
# ...         ...   ...     ...        ...           ...
# 6492    0.99490  3.45    10.5          5           1.0
# 6493    0.99512  3.52    11.2          6           1.0
# 6494    0.99574  3.42    11.0          6           1.0
# 6495    0.99547  3.57    10.2          5           1.0
# 6496    0.99549  3.39    11.0          6           1.0
#
# [6497 rows x 10 columns]

# %% [markdown]
# QUAL METODO QUE USAMOS(RANDOM FOREST) OQUE ELE E NO QUE ELE AJUDA.

# %%
#Limpamos todos os dados nulos por meio dessas ferrafemtas

# Retirando data perdido no dataframe.
data_acidez = ~novo.acidez.isnull()
data_volatilidade = ~novo.volatilidadeAcida.isnull()
data_critica = ~novo.AcidezCitrica.isnull()
data_acucar = ~novo.AçucarResidual.isnull()
data_ph = ~novo.pH.isnull()
filtrado = novo[data_acidez & data_volatilidade & data_critica & data_acucar & data_ph].copy()
# Verificando as informações perdidas no dataset.
filtrado.isnull().sum()
# Out:
# tipo                 0
# acidez               0
# volatilidadeAcida    0
# AcidezCitrica        0
# AçucarResidual       0
# densidade            0
# pH                   0
# álcool               0
# Qualidade            0
# Tipo Binário         0
# dtype: int64

# %%
# separamos as colonas para mostrar nossas features e a nossa informacao alvo
X = filtrado.iloc[:,1:9].values # ESSES SAO OS FEATURES
Y = filtrado.iloc[:,9].values  # ESSE É O TARGET 
Z = X, Y

# %%
#separamos em duas tabelas uma teste e outra de treino
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
# Utilizamos o metodo random forest para prever o tipo de vinho 
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=20, random_state=0)
classifier.fit(X_train, y_train)
Y_pred = classifier.predict(X_test)
Y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# Vendo a acuracia
classifier.score(X_test, y_test)
# Out:
# 0.9829984544049459

# %% [markdown]
#  a acuracia é boa pq nesse metodo.

# %% [markdown]
# Vendo dados estatisticos da tabela e analisando seus valores

# %% [markdown]
# PEQUENA CONCLUSAO DO METODO

# %%
# vendo os dados estátísticos Básicos da tabela
novo.describe()
# Out:
#             acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# count  6487.000000        6489.000000    6494.000000     6495.000000
# mean      7.216579           0.339691       0.318722        5.444326
# std       1.296750           0.164649       0.145265        4.758125
# min       3.800000           0.080000       0.000000        0.600000
# 25%       6.400000           0.230000       0.250000        1.800000
# 50%       7.000000           0.290000       0.310000        3.000000
# 75%       7.700000           0.400000       0.390000        8.100000
# max      15.900000           1.580000       1.660000       65.800000
#
#          densidade           pH       álcool    Qualidade  Tipo Binário
# count  6497.000000  6488.000000  6497.000000  6497.000000   6497.000000
# mean      0.994697     3.218395    10.491801     5.818378      0.246114
# std       0.002999     0.160748     1.192712     0.873255      0.430779
# min       0.987110     2.720000     8.000000     3.000000      0.000000
# 25%       0.992340     3.110000     9.500000     5.000000      0.000000
# 50%       0.994890     3.210000    10.300000     6.000000      0.000000
# 75%       0.996990     3.320000    11.300000     6.000000      0.000000
# max       1.038980     4.010000    14.900000     9.000000      1.000000

# %%
novo.tipo.describe()
# Out:
# count      6497
# unique        2
# top       white
# freq       4898
# Name: tipo, dtype: object

# %%
novo.tipo.value_counts(True)
# Out:
# white    0.753886
# red      0.246114
# Name: tipo, dtype: float64

# %% [markdown]
# A partir da tabale criada usando a ferramenta describe() no dataset, podemos perceber que ha mais vinho branco que vermelho.

# %% [markdown]
# VAMOS ANALISAR OS TIPOS DE VINHO SEPARADAMENTE PARA VER SUAS ESTATISTICAS

# %%
novo[novo.tipo == 'white'].describe()
# Out:
#             acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# count  4890.000000        4891.000000    4896.000000     4896.000000
# mean      6.855532           0.278252       0.334250        6.393250
# std       0.843808           0.100811       0.120985        5.072275
# min       3.800000           0.080000       0.000000        0.600000
# 25%       6.300000           0.210000       0.270000        1.700000
# 50%       6.800000           0.260000       0.320000        5.200000
# 75%       7.300000           0.320000       0.390000        9.900000
# max      14.200000           1.100000       1.660000       65.800000
#
#          densidade           pH       álcool    Qualidade  Tipo Binário
# count  4898.000000  4891.000000  4898.000000  4898.000000        4898.0
# mean      0.994027     3.188203    10.514267     5.877909           0.0
# std       0.002991     0.151014     1.230621     0.885639           0.0
# min       0.987110     2.720000     8.000000     3.000000           0.0
# 25%       0.991723     3.090000     9.500000     5.000000           0.0
# 50%       0.993740     3.180000    10.400000     6.000000           0.0
# 75%       0.996100     3.280000    11.400000     6.000000           0.0
# max       1.038980     3.820000    14.200000     9.000000           0.0

# %%
novo[novo.tipo == 'red'].describe()
# Out:
#             acidez  volatilidadeAcida  AcidezCitrica  AçucarResidual  \
# count  1597.000000        1598.000000    1598.000000     1599.000000
# mean      8.322104           0.527738       0.271145        2.538806
# std       1.740767           0.179085       0.194744        1.409928
# min       4.600000           0.120000       0.000000        0.900000
# 25%       7.100000           0.390000       0.090000        1.900000
# 50%       7.900000           0.520000       0.260000        2.200000
# 75%       9.200000           0.640000       0.420000        2.600000
# max      15.900000           1.580000       1.000000       15.500000
#
#          densidade           pH       álcool    Qualidade  Tipo Binário
# count  1599.000000  1597.000000  1599.000000  1599.000000        1599.0
# mean      0.996747     3.310864    10.422983     5.636023           1.0
# std       0.001887     0.154290     1.065668     0.807569           0.0
# min       0.990070     2.740000     8.400000     3.000000           1.0
# 25%       0.995600     3.210000     9.500000     5.000000           1.0
# 50%       0.996750     3.310000    10.200000     6.000000           1.0
# 75%       0.997835     3.400000    11.100000     6.000000           1.0
# max       1.003690     4.010000    14.900000     8.000000           1.0

# %% [markdown]
# Olhando para as duas tabelas acima,
# podemos concluir que o vinho vermelho é mais ácido que o vinho branco.
# Mostrando uma maior acidez em seus quartis e um maximo maior.

# %% [markdown]
# AQUI EXPLICAMOS SOBRE O METODO DECISION TREE PQ ELE É IMPORTANTE E COMO DEVE SER USADO

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics

features = ['acidez', 'volatilidadeAcida', 'AcidezCitrica', 'AçucarResidual','densidade','pH','álcool', 'Qualidade']
X = filtrado[features] # Features
y = filtrado['Tipo Binário'] # Target variable
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(X, Y)
decision_tree
tree.plot_tree(clf)
# Out:
# [Text(226.45160065874038, 211.04470588235293, 'X[1] <= 0.412\ngini = 0.372\nsamples = 6468\nvalue = [4873, 1595]'),
#  Text(171.67980800128535, 198.25411764705882, 'X[0] <= 9.25\ngini = 0.175\nsamples = 4944\nvalue = [4466, 478]'),
#  Text(132.4958627892031, 185.4635294117647, 'X[0] <= 7.85\ngini = 0.115\nsamples = 4719\nvalue = [4431, 288]'),
#  Text(83.82103149100257, 172.6729411764706, 'X[1] <= 0.358\ngini = 0.067\nsamples = 4121\nvalue = [3979, 142]'),
#  Text(41.4465616966581, 159.88235294117646, 'X[5] <= 3.285\ngini = 0.032\nsamples = 3662\nvalue = [3602, 60]'),
#  Text(15.49203084832905, 147.09176470588235, 'X[3] <= 3.55\ngini = 0.008\nsamples = 2638\nvalue = [2628, 10]'),
#  Text(13.7706940874036, 134.30117647058825, 'X[4] <= 0.995\ngini = 0.021\nsamples = 958\nvalue = [948, 10]'),
#  Text(8.60668380462725, 121.51058823529411, 'X[3] <= 2.35\ngini = 0.01\nsamples = 952\nvalue = [947, 5]'),
#  Text(3.4426735218509, 108.72, 'X[5] <= 3.245\ngini = 0.003\nsamples = 785\nvalue = [784, 1]'),
#  Text(1.72133676092545, 95.92941176470588, 'gini = 0.0\nsamples = 668\nvalue = [668, 0]'),
#  Text(5.16401028277635, 95.92941176470588, 'X[2] <= 0.395\ngini = 0.017\nsamples = 117\nvalue = [116, 1]'),
#  Text(3.4426735218509, 83.13882352941175, 'gini = 0.0\nsamples = 99\nvalue = [99, 0]'),
#  Text(6.8853470437018, 83.13882352941175, 'X[0] <= 6.15\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(5.16401028277635, 70.34823529411764, 'X[1] <= 0.205\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(3.4426735218509, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6.8853470437018, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(8.60668380462725, 70.34823529411764, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(13.7706940874036, 108.72, 'X[5] <= 3.205\ngini = 0.047\nsamples = 167\nvalue = [163, 4]'),
#  Text(12.04935732647815, 95.92941176470588, 'gini = 0.0\nsamples = 123\nvalue = [123, 0]'),
#  Text(15.49203084832905, 95.92941176470588, 'X[4] <= 0.994\ngini = 0.165\nsamples = 44\nvalue = [40, 4]'),
#  Text(13.7706940874036, 83.13882352941175, 'X[0] <= 6.65\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(12.04935732647815, 70.34823529411764, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(15.49203084832905, 70.34823529411764, 'X[3] <= 2.7\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(13.7706940874036, 57.557647058823534, 'X[6] <= 12.25\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(12.04935732647815, 44.767058823529396, 'X[4] <= 0.991\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(10.3280205655527, 31.976470588235287, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(13.7706940874036, 31.976470588235287, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(15.49203084832905, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(17.2133676092545, 57.557647058823534, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(17.2133676092545, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(18.93470437017995, 121.51058823529411, 'X[6] <= 9.2\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(17.2133676092545, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(20.6560411311054, 108.72, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(17.2133676092545, 134.30117647058825, 'gini = 0.0\nsamples = 1680\nvalue = [1680, 0]'),
#  Text(67.40109254498715, 147.09176470588235, 'X[1] <= 0.303\ngini = 0.093\nsamples = 1024\nvalue = [974, 50]'),
#  Text(52.1780205655527, 134.30117647058825, 'X[0] <= 7.35\ngini = 0.044\nsamples = 839\nvalue = [820, 19]'),
#  Text(42.3879177377892, 121.51058823529411, 'X[2] <= 0.435\ngini = 0.028\nsamples = 773\nvalue = [762, 11]'),
#  Text(34.857069408740365, 108.72, 'X[6] <= 13.35\ngini = 0.017\nsamples = 707\nvalue = [701, 6]'),
#  Text(30.123393316195376, 95.92941176470588, 'X[5] <= 3.495\ngini = 0.014\nsamples = 700\nvalue = [695, 5]'),
#  Text(25.82005141388175, 83.13882352941175, 'X[2] <= 0.255\ngini = 0.007\nsamples = 607\nvalue = [605, 2]'),
#  Text(24.0987146529563, 70.34823529411764, 'X[3] <= 13.35\ngini = 0.032\nsamples = 124\nvalue = [122, 2]'),
#  Text(20.6560411311054, 57.557647058823534, 'X[1] <= 0.195\ngini = 0.018\nsamples = 112\nvalue = [111, 1]'),
#  Text(18.93470437017995, 44.767058823529396, 'X[7] <= 5.5\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(17.2133676092545, 31.976470588235287, 'X[1] <= 0.185\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(15.49203084832905, 19.185882352941178, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(18.93470437017995, 19.185882352941178, 'X[3] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(17.2133676092545, 6.39529411764704, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(20.6560411311054, 6.39529411764704, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(20.6560411311054, 31.976470588235287, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(22.37737789203085, 44.767058823529396, 'gini = 0.0\nsamples = 87\nvalue = [87, 0]'),
#  Text(27.5413881748072, 57.557647058823534, 'X[3] <= 14.175\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(25.82005141388175, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(29.26272493573265, 44.767058823529396, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(27.5413881748072, 70.34823529411764, 'gini = 0.0\nsamples = 483\nvalue = [483, 0]'),
#  Text(34.426735218509, 83.13882352941175, 'X[0] <= 6.95\ngini = 0.062\nsamples = 93\nvalue = [90, 3]'),
#  Text(32.70539845758355, 70.34823529411764, 'gini = 0.0\nsamples = 79\nvalue = [79, 0]'),
#  Text(36.14807197943445, 70.34823529411764, 'X[6] <= 10.8\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(34.426735218509, 57.557647058823534, 'X[4] <= 0.997\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(32.70539845758355, 44.767058823529396, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(36.14807197943445, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(37.8694087403599, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(39.59074550128535, 95.92941176470588, 'X[4] <= 0.991\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(37.8694087403599, 83.13882352941175, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(41.3120822622108, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(49.918766066838046, 108.72, 'X[6] <= 12.3\ngini = 0.14\nsamples = 66\nvalue = [61, 5]'),
#  Text(46.47609254498715, 95.92941176470588, 'X[4] <= 0.995\ngini = 0.092\nsamples = 62\nvalue = [59, 3]'),
#  Text(44.7547557840617, 83.13882352941175, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(48.1974293059126, 83.13882352941175, 'X[3] <= 2.25\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(46.47609254498715, 70.34823529411764, 'X[6] <= 9.85\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(44.7547557840617, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(48.1974293059126, 57.557647058823534, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(49.918766066838046, 70.34823529411764, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(53.361439588688945, 95.92941176470588, 'X[6] <= 12.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(51.6401028277635, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(55.0827763496144, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(61.9681233933162, 121.51058823529411, 'X[6] <= 10.75\ngini = 0.213\nsamples = 66\nvalue = [58, 8]'),
#  Text(58.5254498714653, 108.72, 'X[1] <= 0.285\ngini = 0.077\nsamples = 50\nvalue = [48, 2]'),
#  Text(56.80411311053985, 95.92941176470588, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(60.24678663239075, 95.92941176470588, 'X[6] <= 9.6\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(58.5254498714653, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(61.9681233933162, 83.13882352941175, 'X[5] <= 3.315\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(60.24678663239075, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(63.68946015424165, 70.34823529411764, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(65.4107969151671, 108.72, 'X[4] <= 0.994\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(63.68946015424165, 95.92941176470588, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(67.13213367609255, 95.92941176470588, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(82.6241645244216, 134.30117647058825, 'X[4] <= 0.995\ngini = 0.279\nsamples = 185\nvalue = [154, 31]'),
#  Text(75.7388174807198, 121.51058823529411, 'X[6] <= 13.95\ngini = 0.062\nsamples = 125\nvalue = [121, 4]'),
#  Text(72.2961439588689, 108.72, 'X[1] <= 0.308\ngini = 0.032\nsamples = 122\nvalue = [120, 2]'),
#  Text(70.57480719794344, 95.92941176470588, 'X[0] <= 6.2\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(68.853470437018, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(72.2961439588689, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(74.01748071979435, 95.92941176470588, 'gini = 0.0\nsamples = 119\nvalue = [119, 0]'),
#  Text(79.1814910025707, 108.72, 'X[7] <= 7.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(77.46015424164524, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(80.90282776349615, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(89.5095115681234, 121.51058823529411, 'X[3] <= 4.85\ngini = 0.495\nsamples = 60\nvalue = [33, 27]'),
#  Text(86.0668380462725, 108.72, 'X[5] <= 3.52\ngini = 0.137\nsamples = 27\nvalue = [2, 25]'),
#  Text(84.34550128534705, 95.92941176470588, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(87.78817480719795, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(92.9521850899743, 108.72, 'X[2] <= 0.595\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(91.23084832904885, 95.92941176470588, 'X[7] <= 4.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(89.5095115681234, 83.13882352941175, 'X[2] <= 0.315\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(87.78817480719795, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.23084832904885, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(92.9521850899743, 83.13882352941175, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(94.67352185089975, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(126.19550128534705, 159.88235294117646, 'X[5] <= 3.315\ngini = 0.293\nsamples = 459\nvalue = [377, 82]'),
#  Text(117.26606683804629, 147.09176470588235, 'X[3] <= 2.65\ngini = 0.09\nsamples = 338\nvalue = [322, 16]'),
#  Text(110.59588688946016, 134.30117647058825, 'X[4] <= 0.995\ngini = 0.268\nsamples = 88\nvalue = [74, 14]'),
#  Text(105.86221079691518, 121.51058823529411, 'X[7] <= 7.5\ngini = 0.077\nsamples = 75\nvalue = [72, 3]'),
#  Text(101.55886889460155, 108.72, 'X[5] <= 3.295\ngini = 0.053\nsamples = 73\nvalue = [71, 2]'),
#  Text(98.11619537275065, 95.92941176470588, 'X[2] <= 0.48\ngini = 0.029\nsamples = 69\nvalue = [68, 1]'),
#  Text(96.3948586118252, 83.13882352941175, 'gini = 0.0\nsamples = 56\nvalue = [56, 0]'),
#  Text(99.83753213367609, 83.13882352941175, 'X[6] <= 11.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(98.11619537275065, 70.34823529411764, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(101.55886889460155, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(105.00154241645245, 95.92941176470588, 'X[6] <= 12.95\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(103.280205655527, 83.13882352941175, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(106.72287917737789, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(110.1655526992288, 108.72, 'X[6] <= 12.2\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(108.44421593830334, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(111.88688946015425, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(115.32956298200514, 121.51058823529411, 'X[1] <= 0.365\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(113.6082262210797, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(117.0508997429306, 108.72, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(123.9362467866324, 134.30117647058825, 'X[3] <= 3.8\ngini = 0.016\nsamples = 250\nvalue = [248, 2]'),
#  Text(122.21491002570694, 121.51058823529411, 'X[4] <= 0.996\ngini = 0.137\nsamples = 27\nvalue = [25, 2]'),
#  Text(120.4935732647815, 108.72, 'X[5] <= 3.265\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(118.77223650385605, 95.92941176470588, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(122.21491002570694, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(123.9362467866324, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(125.65758354755785, 121.51058823529411, 'gini = 0.0\nsamples = 223\nvalue = [223, 0]'),
#  Text(135.12493573264783, 147.09176470588235, 'X[4] <= 0.993\ngini = 0.496\nsamples = 121\nvalue = [55, 66]'),
#  Text(130.8215938303342, 134.30117647058825, 'X[0] <= 5.05\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(129.10025706940874, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(132.54293059125965, 121.51058823529411, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(139.42827763496146, 134.30117647058825, 'X[3] <= 3.25\ngini = 0.397\nsamples = 88\nvalue = [24, 64]'),
#  Text(135.98560411311055, 121.51058823529411, 'X[4] <= 0.995\ngini = 0.187\nsamples = 67\nvalue = [7, 60]'),
#  Text(134.2642673521851, 108.72, 'X[6] <= 10.95\ngini = 0.465\nsamples = 19\nvalue = [7, 12]'),
#  Text(132.54293059125965, 95.92941176470588, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(135.98560411311055, 95.92941176470588, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(137.706940874036, 108.72, 'gini = 0.0\nsamples = 48\nvalue = [0, 48]'),
#  Text(142.87095115681234, 121.51058823529411, 'X[6] <= 12.05\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(141.14961439588689, 108.72, 'X[4] <= 0.998\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(139.42827763496146, 95.92941176470588, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(142.87095115681234, 95.92941176470588, 'X[6] <= 9.6\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(141.14961439588689, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(144.5922879177378, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(144.5922879177378, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(181.1706940874036, 172.6729411764706, 'X[5] <= 3.255\ngini = 0.369\nsamples = 598\nvalue = [452, 146]'),
#  Text(167.83033419023138, 159.88235294117646, 'X[5] <= 3.195\ngini = 0.169\nsamples = 451\nvalue = [409, 42]'),
#  Text(156.64164524421594, 147.09176470588235, 'X[2] <= 0.115\ngini = 0.102\nsamples = 389\nvalue = [368, 21]'),
#  Text(154.92030848329048, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(158.3629820051414, 134.30117647058825, 'X[1] <= 0.285\ngini = 0.098\nsamples = 388\nvalue = [368, 20]'),
#  Text(151.4776349614396, 121.51058823529411, 'X[6] <= 12.6\ngini = 0.045\nsamples = 262\nvalue = [256, 6]'),
#  Text(148.0349614395887, 108.72, 'X[0] <= 8.75\ngini = 0.031\nsamples = 257\nvalue = [253, 4]'),
#  Text(146.31362467866325, 95.92941176470588, 'gini = 0.0\nsamples = 212\nvalue = [212, 0]'),
#  Text(149.75629820051415, 95.92941176470588, 'X[4] <= 0.999\ngini = 0.162\nsamples = 45\nvalue = [41, 4]'),
#  Text(148.0349614395887, 83.13882352941175, 'X[5] <= 3.11\ngini = 0.127\nsamples = 44\nvalue = [41, 3]'),
#  Text(146.31362467866325, 70.34823529411764, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(149.75629820051415, 70.34823529411764, 'X[6] <= 11.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(148.0349614395887, 57.557647058823534, 'X[5] <= 3.125\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(146.31362467866325, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(149.75629820051415, 44.767058823529396, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(151.4776349614396, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(151.4776349614396, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(154.92030848329048, 108.72, 'X[3] <= 1.25\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(153.19897172236506, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(156.64164524421594, 95.92941176470588, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(165.2483290488432, 121.51058823529411, 'X[3] <= 2.55\ngini = 0.198\nsamples = 126\nvalue = [112, 14]'),
#  Text(161.8056555269923, 108.72, 'X[3] <= 1.75\ngini = 0.386\nsamples = 46\nvalue = [34, 12]'),
#  Text(160.08431876606684, 95.92941176470588, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(163.52699228791775, 95.92941176470588, 'X[4] <= 0.993\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(161.8056555269923, 83.13882352941175, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(165.2483290488432, 83.13882352941175, 'X[5] <= 3.185\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(163.52699228791775, 70.34823529411764, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(166.96966580976866, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(168.6910025706941, 108.72, 'X[2] <= 0.66\ngini = 0.049\nsamples = 80\nvalue = [78, 2]'),
#  Text(166.96966580976866, 95.92941176470588, 'gini = 0.0\nsamples = 71\nvalue = [71, 0]'),
#  Text(170.41233933161953, 95.92941176470588, 'X[6] <= 11.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(168.6910025706941, 83.13882352941175, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(172.133676092545, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(179.0190231362468, 147.09176470588235, 'X[1] <= 0.335\ngini = 0.448\nsamples = 62\nvalue = [41, 21]'),
#  Text(175.5763496143959, 134.30117647058825, 'X[0] <= 8.15\ngini = 0.32\nsamples = 50\nvalue = [40, 10]'),
#  Text(173.85501285347044, 121.51058823529411, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(177.29768637532135, 121.51058823529411, 'X[3] <= 5.25\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(175.5763496143959, 108.72, 'X[4] <= 0.993\ngini = 0.499\nsamples = 21\nvalue = [11, 10]'),
#  Text(173.85501285347044, 95.92941176470588, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(177.29768637532135, 95.92941176470588, 'X[1] <= 0.195\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(175.5763496143959, 83.13882352941175, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(179.0190231362468, 83.13882352941175, 'X[2] <= 0.285\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(177.29768637532135, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(180.74035989717225, 70.34823529411764, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(179.0190231362468, 108.72, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(182.4616966580977, 134.30117647058825, 'X[5] <= 3.245\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(180.74035989717225, 121.51058823529411, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(184.18303341902313, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(194.51105398457585, 159.88235294117646, 'X[3] <= 6.65\ngini = 0.414\nsamples = 147\nvalue = [43, 104]'),
#  Text(192.7897172236504, 147.09176470588235, 'X[1] <= 0.175\ngini = 0.271\nsamples = 124\nvalue = [20, 104]'),
#  Text(189.3470437017995, 134.30117647058825, 'X[1] <= 0.13\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(187.62570694087404, 121.51058823529411, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(191.06838046272495, 121.51058823529411, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(196.2323907455013, 134.30117647058825, 'X[4] <= 0.993\ngini = 0.164\nsamples = 111\nvalue = [10, 101]'),
#  Text(194.51105398457585, 121.51058823529411, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(197.95372750642676, 121.51058823529411, 'X[1] <= 0.275\ngini = 0.106\nsamples = 107\nvalue = [6, 101]'),
#  Text(194.51105398457585, 108.72, 'X[3] <= 2.6\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(192.7897172236504, 95.92941176470588, 'X[1] <= 0.255\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(191.06838046272495, 83.13882352941175, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(194.51105398457585, 83.13882352941175, 'X[5] <= 3.27\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(192.7897172236504, 70.34823529411764, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(196.2323907455013, 70.34823529411764, 'X[7] <= 6.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(194.51105398457585, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(197.95372750642676, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(196.2323907455013, 95.92941176470588, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(201.39640102827764, 108.72, 'X[3] <= 4.8\ngini = 0.024\nsamples = 82\nvalue = [1, 81]'),
#  Text(199.67506426735218, 95.92941176470588, 'gini = 0.0\nsamples = 75\nvalue = [0, 75]'),
#  Text(203.1177377892031, 95.92941176470588, 'X[0] <= 8.2\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(201.39640102827764, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(204.83907455012854, 83.13882352941175, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(196.2323907455013, 147.09176470588235, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(210.86375321336763, 185.4635294117647, 'X[4] <= 0.994\ngini = 0.263\nsamples = 225\nvalue = [35, 190]'),
#  Text(209.14241645244218, 172.6729411764706, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(212.58508997429308, 172.6729411764706, 'X[3] <= 7.0\ngini = 0.179\nsamples = 211\nvalue = [21, 190]'),
#  Text(207.42107969151672, 159.88235294117646, 'X[1] <= 0.175\ngini = 0.105\nsamples = 198\nvalue = [11, 187]'),
#  Text(205.69974293059127, 147.09176470588235, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(209.14241645244218, 147.09176470588235, 'X[3] <= 1.35\ngini = 0.07\nsamples = 194\nvalue = [7, 187]'),
#  Text(207.42107969151672, 134.30117647058825, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(210.86375321336763, 134.30117647058825, 'X[7] <= 4.5\ngini = 0.051\nsamples = 192\nvalue = [5, 187]'),
#  Text(206.560411311054, 121.51058823529411, 'X[0] <= 9.8\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(204.83907455012854, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(208.28174807197945, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(215.16709511568124, 121.51058823529411, 'X[2] <= 0.305\ngini = 0.031\nsamples = 189\nvalue = [3, 186]'),
#  Text(211.72442159383036, 108.72, 'X[2] <= 0.27\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(210.0030848329049, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(213.44575835475578, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(218.60976863753214, 108.72, 'X[1] <= 0.255\ngini = 0.011\nsamples = 186\nvalue = [1, 185]'),
#  Text(216.8884318766067, 95.92941176470588, 'X[1] <= 0.245\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(215.16709511568124, 83.13882352941175, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(218.60976863753214, 83.13882352941175, 'X[0] <= 10.1\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(216.8884318766067, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(220.3311053984576, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(220.3311053984576, 95.92941176470588, 'gini = 0.0\nsamples = 167\nvalue = [0, 167]'),
#  Text(217.74910025706941, 159.88235294117646, 'X[6] <= 10.75\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(216.02776349614396, 147.09176470588235, 'X[4] <= 1.002\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(214.3064267352185, 134.30117647058825, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(217.74910025706941, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(219.47043701799487, 147.09176470588235, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(281.22339331619537, 198.25411764705882, 'X[3] <= 4.35\ngini = 0.391\nsamples = 1524\nvalue = [407, 1117]'),
#  Text(244.1070694087404, 185.4635294117647, 'X[4] <= 0.993\ngini = 0.236\nsamples = 1207\nvalue = [165, 1042]'),
#  Text(230.6591259640103, 172.6729411764706, 'X[5] <= 3.495\ngini = 0.322\nsamples = 154\nvalue = [123, 31]'),
#  Text(226.35578406169668, 159.88235294117646, 'X[5] <= 3.295\ngini = 0.178\nsamples = 132\nvalue = [119, 13]'),
#  Text(222.91311053984577, 147.09176470588235, 'X[0] <= 7.75\ngini = 0.041\nsamples = 95\nvalue = [93, 2]'),
#  Text(221.19177377892032, 134.30117647058825, 'gini = 0.0\nsamples = 85\nvalue = [85, 0]'),
#  Text(224.63444730077123, 134.30117647058825, 'X[6] <= 12.9\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(222.91311053984577, 121.51058823529411, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(226.35578406169668, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(229.79845758354756, 147.09176470588235, 'X[4] <= 0.992\ngini = 0.418\nsamples = 37\nvalue = [26, 11]'),
#  Text(228.0771208226221, 134.30117647058825, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(231.519794344473, 134.30117647058825, 'X[6] <= 10.45\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(229.79845758354756, 121.51058823529411, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(233.24113110539847, 121.51058823529411, 'X[0] <= 4.95\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(231.519794344473, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(234.96246786632392, 108.72, 'X[1] <= 0.465\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(233.24113110539847, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(236.68380462724937, 95.92941176470588, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(234.96246786632392, 159.88235294117646, 'X[6] <= 11.65\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(233.24113110539847, 147.09176470588235, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(236.68380462724937, 147.09176470588235, 'X[3] <= 2.95\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(234.96246786632392, 134.30117647058825, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(238.40514138817483, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(257.55501285347043, 172.6729411764706, 'X[3] <= 1.15\ngini = 0.077\nsamples = 1053\nvalue = [42, 1011]'),
#  Text(255.833676092545, 159.88235294117646, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(259.2763496143959, 159.88235294117646, 'X[4] <= 0.995\ngini = 0.065\nsamples = 1046\nvalue = [35, 1011]'),
#  Text(249.59383033419024, 147.09176470588235, 'X[5] <= 3.25\ngini = 0.29\nsamples = 159\nvalue = [28, 131]'),
#  Text(243.56915167095116, 134.30117647058825, 'X[4] <= 0.995\ngini = 0.48\nsamples = 35\nvalue = [21, 14]'),
#  Text(240.12647814910028, 121.51058823529411, 'X[2] <= 0.075\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(238.40514138817483, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(241.84781491002573, 108.72, 'X[6] <= 11.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(240.12647814910028, 95.92941176470588, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(243.56915167095116, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(247.01182519280206, 121.51058823529411, 'X[7] <= 4.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(245.2904884318766, 108.72, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(248.73316195372752, 108.72, 'X[0] <= 8.85\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(247.01182519280206, 95.92941176470588, 'X[5] <= 3.215\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(245.2904884318766, 83.13882352941175, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(248.73316195372752, 83.13882352941175, 'X[6] <= 10.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(247.01182519280206, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(250.45449871465297, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(250.45449871465297, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(255.61850899742933, 134.30117647058825, 'X[6] <= 9.45\ngini = 0.107\nsamples = 124\nvalue = [7, 117]'),
#  Text(253.89717223650388, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(257.3398457583548, 121.51058823529411, 'X[6] <= 10.65\ngini = 0.079\nsamples = 122\nvalue = [5, 117]'),
#  Text(255.61850899742933, 108.72, 'X[2] <= 0.25\ngini = 0.271\nsamples = 31\nvalue = [5, 26]'),
#  Text(253.89717223650388, 95.92941176470588, 'X[0] <= 4.8\ngini = 0.133\nsamples = 28\nvalue = [2, 26]'),
#  Text(252.17583547557842, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(255.61850899742933, 83.13882352941175, 'X[0] <= 5.55\ngini = 0.071\nsamples = 27\nvalue = [1, 26]'),
#  Text(253.89717223650388, 70.34823529411764, 'X[0] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(252.17583547557842, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(255.61850899742933, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(257.3398457583548, 70.34823529411764, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(257.3398457583548, 95.92941176470588, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(259.06118251928024, 108.72, 'gini = 0.0\nsamples = 91\nvalue = [0, 91]'),
#  Text(268.95886889460155, 147.09176470588235, 'X[6] <= 8.6\ngini = 0.016\nsamples = 887\nvalue = [7, 880]'),
#  Text(262.50385604113114, 134.30117647058825, 'X[5] <= 3.195\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(260.7825192802057, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(264.2251928020566, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(275.413881748072, 134.30117647058825, 'X[7] <= 4.5\ngini = 0.013\nsamples = 885\nvalue = [6, 879]'),
#  Text(267.66786632390745, 121.51058823529411, 'X[5] <= 3.135\ngini = 0.127\nsamples = 44\nvalue = [3, 41]'),
#  Text(264.2251928020566, 108.72, 'X[2] <= 0.48\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(262.50385604113114, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(265.946529562982, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(271.11053984575835, 108.72, 'X[3] <= 3.15\ngini = 0.049\nsamples = 40\nvalue = [1, 39]'),
#  Text(269.3892030848329, 95.92941176470588, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]'),
#  Text(272.8318766066838, 95.92941176470588, 'X[3] <= 3.25\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(271.11053984575835, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(274.55321336760926, 83.13882352941175, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(283.1598971722365, 121.51058823529411, 'X[1] <= 0.455\ngini = 0.007\nsamples = 841\nvalue = [3, 838]'),
#  Text(281.4385604113111, 108.72, 'X[4] <= 0.996\ngini = 0.059\nsamples = 98\nvalue = [3, 95]'),
#  Text(279.7172236503856, 95.92941176470588, 'X[6] <= 10.15\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(277.99588688946017, 83.13882352941175, 'X[2] <= 0.225\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(276.2745501285347, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(279.7172236503856, 70.34823529411764, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(281.4385604113111, 83.13882352941175, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(283.1598971722365, 95.92941176470588, 'gini = 0.0\nsamples = 88\nvalue = [0, 88]'),
#  Text(284.881233933162, 108.72, 'gini = 0.0\nsamples = 743\nvalue = [0, 743]'),
#  Text(318.3397172236504, 185.4635294117647, 'X[0] <= 9.85\ngini = 0.361\nsamples = 317\nvalue = [242, 75]'),
#  Text(311.3467866323908, 172.6729411764706, 'X[5] <= 3.295\ngini = 0.292\nsamples = 293\nvalue = [241, 52]'),
#  Text(302.5249357326478, 159.88235294117646, 'X[1] <= 0.718\ngini = 0.098\nsamples = 214\nvalue = [203, 11]'),
#  Text(297.79125964010285, 147.09176470588235, 'X[0] <= 8.8\ngini = 0.057\nsamples = 204\nvalue = [198, 6]'),
#  Text(293.48791773778925, 134.30117647058825, 'X[1] <= 0.625\ngini = 0.04\nsamples = 197\nvalue = [193, 4]'),
#  Text(290.04524421593834, 121.51058823529411, 'X[1] <= 0.422\ngini = 0.011\nsamples = 180\nvalue = [179, 1]'),
#  Text(288.3239074550129, 108.72, 'X[6] <= 11.25\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(286.60257069408743, 95.92941176470588, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(290.04524421593834, 95.92941176470588, 'X[3] <= 7.7\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(288.3239074550129, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(291.7665809768638, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(291.7665809768638, 108.72, 'gini = 0.0\nsamples = 161\nvalue = [161, 0]'),
#  Text(296.9305912596401, 121.51058823529411, 'X[1] <= 0.635\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(295.20925449871464, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(298.65192802056555, 108.72, 'X[5] <= 3.27\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(296.9305912596401, 95.92941176470588, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(300.373264781491, 95.92941176470588, 'X[5] <= 3.285\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(298.65192802056555, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(302.09460154241646, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(302.09460154241646, 134.30117647058825, 'X[4] <= 0.997\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(300.373264781491, 121.51058823529411, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(303.8159383033419, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(307.2586118251928, 147.09176470588235, 'X[5] <= 3.155\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(305.53727506426736, 134.30117647058825, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(308.97994858611827, 134.30117647058825, 'X[4] <= 0.997\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(307.2586118251928, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(310.7012853470437, 121.51058823529411, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(320.1686375321337, 159.88235294117646, 'X[0] <= 6.45\ngini = 0.499\nsamples = 79\nvalue = [38, 41]'),
#  Text(314.14395886889463, 147.09176470588235, 'X[5] <= 3.535\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(312.4226221079692, 134.30117647058825, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(315.8652956298201, 134.30117647058825, 'X[3] <= 5.4\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(314.14395886889463, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(317.58663239074554, 121.51058823529411, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(326.19331619537274, 147.09176470588235, 'X[3] <= 8.0\ngini = 0.413\nsamples = 55\nvalue = [16, 39]'),
#  Text(322.7506426735219, 134.30117647058825, 'X[3] <= 7.05\ngini = 0.095\nsamples = 40\nvalue = [2, 38]'),
#  Text(321.02930591259644, 121.51058823529411, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]'),
#  Text(324.4719794344473, 121.51058823529411, 'X[2] <= 0.29\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(322.7506426735219, 108.72, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(326.19331619537274, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(329.63598971722365, 134.30117647058825, 'X[5] <= 3.43\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(327.9146529562982, 121.51058823529411, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(331.3573264781491, 121.51058823529411, 'X[0] <= 7.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(329.63598971722365, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(333.07866323907456, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(325.33264781491005, 172.6729411764706, 'X[5] <= 3.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(323.6113110539846, 159.88235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(327.0539845758355, 159.88235294117646, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]')]

# %% [markdown]
# PEQUENA CONCLUSAO DO METODO

# %% [markdown]
# MELHORIAS QUE PODIAMOS FAZER

# %% [markdown]
# CONCLUSAO GERAL

# %% [markdown]
# REFERENCIAS
